# %% [markdown]
# <a href="https://colab.research.google.com/github/ArnobTurja2002Ghosh/gistemp/blob/main/SH.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors

df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/SH.Ts+dSST_1.csv')
df['Decade']=df['Year']//10 *10
df1=df[::-1].reset_index()

# %%
df
# Out:
#      Year   Jan    Feb    Mar    Apr    May    Jun    Jul    Aug    Sep  \
# 0    1880  0.01   0.04   0.07  -0.01  -0.12  -0.24  -0.16   0.07  -0.04
# 1    1881 -0.08  -0.05    0.1   0.11   0.09  -0.04  -0.07  -0.02  -0.03
# 2    1882  0.07   0.08   0.08  -0.01  -0.03  -0.14  -0.03   0.02  -0.03
# 3    1883 -0.02  -0.07  -0.08  -0.06  -0.09  -0.01  -0.07  -0.05  -0.09
# 4    1884 -0.08  -0.04  -0.09   -0.2  -0.31  -0.28  -0.21  -0.06   -0.1
# ..    ...   ...    ...    ...    ...    ...    ...    ...    ...    ...
# 140  2020  0.75   0.77   0.67   0.85   0.75    0.7   0.69   0.62   0.76
# 141  2021  0.34   0.31   0.56   0.38   0.53   0.48   0.76   0.62   0.79
# 142  2022  0.56   0.61   0.66   0.58   0.66   0.71   0.81   0.72   0.62
# 143  2023  0.44   0.62    0.8   0.97   0.76   0.98   0.95   0.83   1.29
# 144  2024  0.80    ***    ***    ***    ***    ***    ***    ***    ***
#
#        Oct    Nov    Dec  Decade
# 0    -0.14   0.01   0.06    1880
# 1     0.01   0.01    0.1    1880
# ...

# %%
df=df[:-5]
df[df.columns[1:-1]]=df[df.columns[1:-1]].apply(pd.to_numeric)
df
# Out:
# <ipython-input-3-1cc4d5a31de2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[df.columns[1:-1]]=df[df.columns[1:-1]].apply(pd.to_numeric)
#      Year   Jan   Feb   Mar   Apr   May   Jun   Jul   Aug   Sep   Oct   Nov  \
# 0    1880  0.01  0.04  0.07 -0.01 -0.12 -0.24 -0.16  0.07 -0.04 -0.14  0.01
# 1    1881 -0.08 -0.05  0.10  0.11  0.09 -0.04 -0.07 -0.02 -0.03  0.01  0.01
# 2    1882  0.07  0.08  0.08 -0.01 -0.03 -0.14 -0.03  0.02 -0.03  0.04  0.00
# 3    1883 -0.02 -0.07 -0.08 -0.06 -0.09 -0.01 -0.07 -0.05 -0.09 -0.05 -0.03
# 4    1884 -0.08 -0.04 -0.09 -0.20 -0.31 -0.28 -0.21 -0.06 -0.10 -0.05 -0.09
# ..    ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 140 entries, 0 to 139
# Data columns (total 14 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Year    140 non-null    int64
#  1   Jan     140 non-null    float64
#  2   Feb     140 non-null    float64
#  3   Mar     140 non-null    float64
#  4   Apr     140 non-null    float64
#  5   May     140 non-null    float64
#  6   Jun     140 non-null    float64
#  7   Jul     140 non-null    float64
#  8   Aug     140 non-null    float64
#  9   Sep     140 non-null    float64
#  10  Oct     140 non-null    float64
#  11  Nov     140 non-null    float64
#  12  Dec     140 non-null    float64
#  13  Decade  140 non-null    int64
# dtypes: float64(12), int64(2)
# memory usage: 15.4 KB

# %%
df_decades=[]
df_molten=[]
for i in df['Decade'].unique():
  df_i=df[df['Decade']==i].copy()
  df_decades.append(df_i)
  df2010s1=df_i.melt(id_vars=['Year','Decade'], value_vars=df_i.columns[1:-1])
  df_molten.append(df2010s1)
df['Decade'].unique()
# Out:
# array([1880, 1890, 1900, 1910, 1920, 1930, 1940, 1950, 1960, 1970, 1980,
#        1990, 2000, 2010])

# %%
color_values=[]
for i in df_molten:
  color_values.append(i['value'].mean())

norm=mcolors.Normalize()
norm.autoscale(color_values)

color_rgba=sns.color_palette("coolwarm", as_cmap=True)(norm(color_values))

# %%
fig, ax = plt.subplots(layout='constrained')

for i,j in enumerate(df_molten):
  sns.histplot(data=j, x="value", zorder=i, element='step', edgecolor='#000000', ax=ax, alpha=1, bins=11, stat='density', color=color_rgba[i])
ax.set(fc="#6ec5fa", title='The Average Southern Hemisphere Temperature Keeps Climbing', ylabel='', xlabel='', ylim=ax.get_ylim(),xticks=[-1, -0.5, 0, 0.5, 1], xticklabels=['', '-0.5', '1951-1980 \n Average', '+0.5', '+1.0 deg C'])
df_1951_1980 = df[(df['Year']>=1951) & (df['Year']<=1980)].copy()
df_1951_1980=df_1951_1980.melt(id_vars=['Year','Decade'], value_vars=df_i.columns[1:-1])
ax.plot([df_1951_1980['value'].mean(), df_1951_1980['value'].mean()], ax.get_ylim(), color='#ffffff', zorder=len(df_molten), linestyle='--')
ax.tick_params(left = False, labelleft = False)

ax.text(-0.5, 4+0.5, 'pre-1950s', color='#ffffff')
ax.text(0.5, 4+0.3, '2000s', color='#ffffff')
ax.text(0.85, 4-2.5, '2010s', color='#ffffff')
# Out:
# Text(0.85, 1.5, '2010s')

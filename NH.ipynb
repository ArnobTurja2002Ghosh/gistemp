# %% [markdown]
# <a href="https://colab.research.google.com/github/ArnobTurja2002Ghosh/gistemp/blob/main/NH.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors

df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/NH.Ts+dSST_1.csv')
df['Decade']=df['Year']//10 *10
df1=df[::-1].reset_index()

# %%
df
# Out:
#      Year   Jan    Feb    Mar    Apr    May    Jun    Jul    Aug    Sep  \
# 0    1880 -0.34  -0.49  -0.22  -0.29  -0.05  -0.15  -0.16  -0.24  -0.21
# 1    1881 -0.29  -0.22  -0.03   0.01   0.05  -0.33   0.09  -0.04  -0.27
# 2    1882  0.27   0.22   0.03   -0.3  -0.23  -0.29  -0.27  -0.13  -0.22
# 3    1883 -0.56  -0.65  -0.14  -0.27  -0.23  -0.12  -0.03  -0.21  -0.31
# 4    1884 -0.15  -0.08  -0.62  -0.58  -0.35  -0.42  -0.39  -0.49  -0.44
# ..    ...   ...    ...    ...    ...    ...    ...    ...    ...    ...
# 140  2020  1.58    1.7   1.65    1.4   1.27   1.12    1.1   1.12    1.2
# 141  2021  1.26   0.95    1.2   1.12   1.03    1.2   1.06   1.02   1.05
# 142  2022  1.24   1.16   1.42   1.08      1   1.12   1.05   1.17   1.15
# 143  2023  1.30   1.32   1.59   1.02   1.11   1.18   1.43   1.57   1.65
# 144  2024  1.62    ***    ***    ***    ***    ***    ***    ***    ***
#
#        Oct    Nov    Dec  Decade
# 0    -0.29   -0.4  -0.38    1880
# 1    -0.44  -0.36  -0.22    1880
# 2    -0.51  -0.32  -0.66    1880
# 3    -0.15  -0.41  -0.14    1880
# 4    -0.44  -0.57  -0.46    1880
# ..     ...    ...    ...     ...
# 140   1.21    1.6    1.2    2020
# 141    1.3    1.3   1.15    2020
# 142   1.31   1.09   1.08    2020
# 143   1.88   1.99   1.85    2020
# 144    ***    ***    ***    2020
#
# [145 rows x 14 columns]

# %%
df=df[:-5]
df[df.columns[1:-1]]=df[df.columns[1:-1]].apply(pd.to_numeric)
df
# Out:
# <ipython-input-3-1cc4d5a31de2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[df.columns[1:-1]]=df[df.columns[1:-1]].apply(pd.to_numeric)
#      Year   Jan   Feb   Mar   Apr   May   Jun   Jul   Aug   Sep   Oct   Nov  \
# 0    1880 -0.34 -0.49 -0.22 -0.29 -0.05 -0.15 -0.16 -0.24 -0.21 -0.29 -0.40
# 1    1881 -0.29 -0.22 -0.03  0.01  0.05 -0.33  0.09 -0.04 -0.27 -0.44 -0.36
# 2    1882  0.27  0.22  0.03 -0.30 -0.23 -0.29 -0.27 -0.13 -0.22 -0.51 -0.32
# 3    1883 -0.56 -0.65 -0.14 -0.27 -0.23 -0.12 -0.03 -0.21 -0.31 -0.15 -0.41
# 4    1884 -0.15 -0.08 -0.62 -0.58 -0.35 -0.42 -0.39 -0.49 -0.44 -0.44 -0.57
# ..    ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 135  2015  1.20  1.19  1.32  1.02  1.04  1.04  0.92  1.01  1.17  1.29  1.38
# 136  2016  1.56  1.94  1.90  1.47  1.11  1.11  1.05  1.12  1.23  1.03  1.12
# 137  2017  1.39  1.52  1.51  1.19  0.92  0.92  0.96  1.02  1.00  1.05  1.22
# 138  2018  1.15  1.24  1.17  0.96  1.00  0.85  0.90  0.87  0.96  1.23  0.97
# 139  2019  1.21  1.11  1.54  1.24  0.98  1.18  1.03  1.09  1.21  1.30  1.19
#
#       Dec  Decade
# 0   -0.38    1880
# 1   -0.22    1880
# 2   -0.66    1880
# 3   -0.14    1880
# 4   -0.46    1880
# ..    ...     ...
# 135  1.55    2010
# 136  1.05    2010
# 137  1.39    2010
# 138  1.09    2010
# 139  1.39    2010
#
# [140 rows x 14 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 140 entries, 0 to 139
# Data columns (total 14 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Year    140 non-null    int64
#  1   Jan     140 non-null    float64
#  2   Feb     140 non-null    float64
#  3   Mar     140 non-null    float64
#  4   Apr     140 non-null    float64
#  5   May     140 non-null    float64
#  6   Jun     140 non-null    float64
#  7   Jul     140 non-null    float64
#  8   Aug     140 non-null    float64
#  9   Sep     140 non-null    float64
#  10  Oct     140 non-null    float64
#  11  Nov     140 non-null    float64
#  12  Dec     140 non-null    float64
#  13  Decade  140 non-null    int64
# dtypes: float64(12), int64(2)
# memory usage: 15.4 KB

# %%
df_decades=[]
df_molten=[]
for i in df['Decade'].unique():
  df_i=df[df['Decade']==i].copy()
  df_decades.append(df_i)
  df2010s1=df_i.melt(id_vars=['Year','Decade'], value_vars=df_i.columns[1:-1])
  df_molten.append(df2010s1)
df['Decade'].unique()
# Out:
# array([1880, 1890, 1900, 1910, 1920, 1930, 1940, 1950, 1960, 1970, 1980,
#        1990, 2000, 2010])

# %%
color_values=[]
for i in df_molten:
  color_values.append(i['value'].mean())

norm=mcolors.Normalize()
norm.autoscale(color_values)

color_rgba=sns.color_palette("coolwarm", as_cmap=True)(norm(color_values))

# %%
fig, ax = plt.subplots(layout='constrained')

for i,j in enumerate(df_molten):
  sns.histplot(data=j, x="value", zorder=i, element='step', edgecolor='#000000', ax=ax, alpha=1, bins=11, stat='density', color=color_rgba[i])
ax.set(fc="#6ec5fa", title='The Average Northern Hemisphere Temperature Keeps Climbing', ylabel='', xlabel='', ylim=ax.get_ylim(),xticks=[-1, -0.5, 0, 0.5, 1], xticklabels=['', '-0.5', '1951-1980 \n Average', '+0.5', '+1.0 deg C'])
df_1951_1980 = df[(df['Year']>=1951) & (df['Year']<=1980)].copy()
df_1951_1980=df_1951_1980.melt(id_vars=['Year','Decade'], value_vars=df_i.columns[1:-1])
ax.plot([df_1951_1980['value'].mean(), df_1951_1980['value'].mean()], ax.get_ylim(), color='#ffffff', zorder=len(df_molten), linestyle='--')
ax.tick_params(left = False, labelleft = False)

ax.text(-0.5, 2.5, 'pre-1950s', color='#ffffff')
ax.text(0.5, 2.5, '2000s', color='#ffffff')
ax.text(0.85, 1.75, '2010s', color='#ffffff')
# Out:
# Text(0.85, 1.75, '2010s')
